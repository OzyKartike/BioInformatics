# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 994.1 kB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.4)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=0.7.0 (from chembl_webresource_client)
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2023.7.22)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0.1)
# Collecting url-normalize<2.0,>=1.4 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jsonschema 4.19.0 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.30.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
import numpy as np
# !pip install rdkit
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 30.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.3.3

# %%
# !pip install seaborn
# !pip install sklearn
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Collecting sklearn
#   Downloading sklearn-0.0.post7.tar.gz (3.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
def mannwhitney(descriptor, verbose=False):
  # https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  active = df[df.bioactivity_class == 'active']
  active = active[descriptor]

  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  inactive = df[df.bioactivity_class == 'inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'

  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem)
        moldata.append(mol)

    baseData= np.arange(1,1)
    i=0
    for mol in moldata:

        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)

        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])

        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1

    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)

    return descriptors

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2023-08-20 18:08:23--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2023-08-20 18:08:24--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M  --.-KB/s    in 0.1s
#
# 2023-08-20 18:08:25 (249 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# --2023-08-20 18:08:25--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh [following]
# --2023-08-20 18:08:25--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231 [text/plain]
# Saving to: ‘padel.sh’
#
# padel.sh            100%[===================>]     231  --.-KB/s    in 0s
#
# 2023-08-20 18:08:26 (17.2 MB/s) - ‘padel.sh’ saved [231/231]

# %% [markdown]
# Identifying the target compound

# %%
# Target search for dopamine d2 receptor
target = new_client.target
target_query = target.search('DRD2')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references                organism  \
# 0   [{'xref_id': 'P14416', 'xref_name': None, 'xre...            Homo sapiens
# 1   [{'xref_id': 'Q9GJU1', 'xref_name': None, 'xre...  Canis lupus familiaris
# 2   [{'xref_id': 'P20288', 'xref_name': None, 'xre...              Bos taurus
# 3   [{'xref_id': 'NBK23195', 'xref_name': 'D2 dopa...            Mus musculus
# 4   [{'xref_id': 'P61169', 'xref_name': None, 'xre...       Rattus norvegicus
# 5   [{'xref_id': 'P52702', 'xref_name': None, 'xre...    Chlorocebus aethiops
# 6                                                  []            Homo sapiens
# 7                                                  []            Homo sapiens
# 8                                                  []       Rattus norvegicus
# 9                                                  []              Bos taurus
# 10                                                 []            Homo sapiens
# 11                                                 []       Rattus norvegicus
# 12                                                 []            Homo sapiens
# 13                                                 []            Homo sapiens
# 14                                                 []            Homo sapiens
# 15                                                 []       Rattus norvegicus
# 16                                                 []            Homo sapiens
# 17                                                 []            Homo sapiens
# 18                                                 []       Rattus norvegicus
# 19                                                 []            Homo sapiens
# 20                                                 []            Mus musculus
# 21                                                 []       Rattus norvegicus
# 22                                                 []            Mus musculus
#
#                                             pref_name  score  \
# 0                                Dopamine D2 receptor   13.0
# 1                                Dopamine D2 receptor   13.0
# 2                                Dopamine D2 receptor   13.0
# 3                                Dopamine D2 receptor   13.0
# 4                                Dopamine D2 receptor   13.0
# 5                                Dopamine D2 receptor   13.0
# 6                         Dopamine receptors; D2 & D3   11.0
# 7                         Dopamine receptors; D2 & D4   11.0
# 8                         Dopamine receptors; D1 & D2   11.0
# 9                                   Dopamine receptor   11.0
# 10                        Dopamine D1 and D2 receptor   11.0
# 11                        Dopamine receptor D2 and D3   11.0
# 12  D(2) dopamine receptor/Metabotropic glutamate ...   11.0
# 13     Dopamine D2 receptor and serotonin 1a receptor   10.0
# 14     Dopamine D2 receptor and serotonin 2a receptor   10.0
# 15  Dopamine D2 receptor and Serotonin 2a receptor...   10.0
# 16    Dopamine receptor D2L/neurotensin receptor NTS1   10.0
# 17                          D2-like dopamine receptor    9.0
# 18                                  Dopamine receptor    7.0
# 19                                  Dopamine receptor    7.0
# 20                                  Dopamine receptor    7.0
# 21  Dopamine D2 receptor/Serotonin 2 (5-HT2) receptor    6.0
# 22  Dopamine D2 receptor/Serotonin 2 (5-HT2) receptor    6.0
#
#     species_group_flag target_chembl_id  \
# 0                False        CHEMBL217
# 1                False       CHEMBL2703
# 2                False       CHEMBL3998
# 3                False       CHEMBL3427
# 4                False        CHEMBL339
# 5                False       CHEMBL5456
# 6                False    CHEMBL2095169
# 7                False    CHEMBL2095396
# 8                False    CHEMBL2096910
# 9                False    CHEMBL2096970
# 10               False    CHEMBL2111341
# 11               False    CHEMBL2111342
# 12               False    CHEMBL4296096
# 13               False    CHEMBL2111460
# 14               False    CHEMBL2111468
# 15               False    CHEMBL2111406
# 16               False    CHEMBL3038478
# 17               False    CHEMBL2331075
# 18               False    CHEMBL2093868
# 19               False    CHEMBL2096905
# 20               False    CHEMBL2111359
# 21               False    CHEMBL2097175
# 22               False    CHEMBL2109245
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P14416', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'Q9GJU1', 'component_descriptio...     SINGLE PROTEIN
# 2   [{'accession': 'P20288', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P61168', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'P61169', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'P52702', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P14416', 'component_descriptio...  SELECTIVITY GROUP
# 7   [{'accession': 'P14416', 'component_descriptio...  SELECTIVITY GROUP
# 8   [{'accession': 'P18901', 'component_descriptio...  SELECTIVITY GROUP
# 9   [{'accession': 'Q95136', 'component_descriptio...     PROTEIN FAMILY
# 10  [{'accession': 'P14416', 'component_descriptio...  SELECTIVITY GROUP
# 11  [{'accession': 'P19020', 'component_descriptio...  SELECTIVITY GROUP
# 12  [{'accession': 'P14416', 'component_descriptio...    PROTEIN COMPLEX
# 13  [{'accession': 'P14416', 'component_descriptio...  SELECTIVITY GROUP
# 14  [{'accession': 'P14416', 'component_descriptio...  SELECTIVITY GROUP
# 15  [{'accession': 'P61169', 'component_descriptio...  SELECTIVITY GROUP
# 16  [{'accession': 'P14416', 'component_descriptio...    PROTEIN COMPLEX
# 17  [{'accession': 'P14416', 'component_descriptio...     PROTEIN FAMILY
# 18  [{'accession': 'P25115', 'component_descriptio...     PROTEIN FAMILY
# 19  [{'accession': 'P14416', 'component_descriptio...     PROTEIN FAMILY
# 20  [{'accession': 'P51436', 'component_descriptio...     PROTEIN FAMILY
# 21  [{'accession': 'P61169', 'component_descriptio...  SELECTIVITY GROUP
# 22  [{'accession': 'Q02152', 'component_descriptio...  SELECTIVITY GROUP
#
#     tax_id
# 0     9606
# 1     9615
# 2     9913
# 3    10090
# 4    10116
# 5     9534
# 6     9606
# 7     9606
# 8    10116
# 9     9913
# 10    9606
# 11   10116
# 12    9606
# 13    9606
# 14    9606
# 15   10116
# 16    9606
# 17    9606
# 18   10116
# 19    9606
# 20   10090
# 21   10116
# 22   10090

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL217'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.to_csv('drd2_bioactivity_data.csv', index=False)

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 2134                                               None             None
# 2135  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2136                                               None             None
# 2137  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 2138  {'action_type': 'ANTAGONIST', 'description': '...             None
#
#       activity_id                                activity_properties  \
# 0           32111                                                 []
# 1           33282                                                 []
# 2           38258                                                 []
# 3           39387                                                 []
# 4           39391                                                 []
# ...           ...                                                ...
# 2134     24421262                                                 []
# 2135     24421263                                                 []
# 2136     24647173  [{'comments': None, 'relation': '=', 'result_f...
# 2137     24749333                                                 []
# 2138     24768417                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL671073  Binding affinity to cloned human Dopamine rece...
# 1       CHEMBL671073  Binding affinity to cloned human Dopamine rece...
# 2       CHEMBL671073  Binding affinity to cloned human Dopamine rece...
# 3       CHEMBL671073  Binding affinity to cloned human Dopamine rece...
# 4       CHEMBL671073  Binding affinity to cloned human Dopamine rece...
# ...              ...                                                ...
# 2134   CHEMBL5048805  Inhibition of dopamine D2 receptor (unknown or...
# 2135   CHEMBL5048805  Inhibition of dopamine D2 receptor (unknown or...
# 2136   CHEMBL5058713               DRD2S Eurofins SafetyScan (Receptor)
# 2137   CHEMBL5120437  Inhibition of dopamine D2 receptor (unknown or...
# 2138   CHEMBL5125561  Antagonist activity at D2 receptor (unknown or...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 2134          B                    None                   None  BAO_0000190
# 2135          B                    None                   None  BAO_0000190
# 2136          B                    None                   None  BAO_0000190
# 2137          B                    None                   None  BAO_0000190
# 2138          F                    None                   None  BAO_0000190
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Dopamine D2 receptor          9606       None
# 1     ...    Homo sapiens  Dopamine D2 receptor          9606       None
# 2     ...    Homo sapiens  Dopamine D2 receptor          9606       None
# 3     ...    Homo sapiens  Dopamine D2 receptor          9606       None
# 4     ...    Homo sapiens  Dopamine D2 receptor          9606       None
# ...   ...             ...                   ...           ...        ...
# 2134  ...    Homo sapiens  Dopamine D2 receptor          9606       None
# 2135  ...    Homo sapiens  Dopamine D2 receptor          9606       None
# 2136  ...    Homo sapiens  Dopamine D2 receptor          9606       None
# 2137  ...    Homo sapiens  Dopamine D2 receptor          9606       None
# 2138  ...    Homo sapiens  Dopamine D2 receptor          9606       None
#
#       toid  type units    uo_units upper_value   value
# 0     None  IC50    nM  UO_0000065        None  9800.0
# 1     None  IC50    nM  UO_0000065        None    50.0
# 2     None  IC50    nM  UO_0000065        None    25.0
# 3     None  IC50    nM  UO_0000065        None   360.0
# 4     None  IC50    nM  UO_0000065        None   300.0
# ...    ...   ...   ...         ...         ...     ...
# 2134  None  IC50    uM  UO_0000065        None    30.0
# 2135  None  IC50    uM  UO_0000065        None     4.1
# 2136  None  IC50    µM        None        None    10.0
# 2137  None  IC50    uM  UO_0000065        None     1.0
# 2138  None  IC50    uM  UO_0000065        None    13.0
#
# [1240 rows x 46 columns]

# %%
#convert the values column to number
df2['value'] = pd.to_numeric(df2['value'], errors='coerce')
# Out:
# <ipython-input-15-0d04c7504a20>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['value'] = pd.to_numeric(df2['value'], errors='coerce')

# %%
mask = df2['units'] == 'uM'
df2.loc[mask, 'value'] = df2.loc[mask, 'value'].apply(lambda x: x*1000)
df2.loc[mask, 'units'] = 'nM'

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
#iterate the values to a  list
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

#combining
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL303519          c1cnc(N2CCN(Cc3cccc4c3Cc3ccccc3-4)CC2)nc1
# 1          CHEMBL292943         COc1ccc(-c2cccc(CN3CCN(c4ncccn4)CC3)c2)cc1
# 2           CHEMBL61682         Fc1ccc(-c2cncc(CN3CCN(c4ccccc4F)CC3)c2)cc1
# 3           CHEMBL64487           COc1ccccc1-c1cccc(CN2CCN(c3ncccn3)CC2)c1
# 4           CHEMBL64597            c1cnc(N2CCN(Cc3cccc(-c4ccsc4)c3)CC2)nc1
# ...                 ...                                                ...
# 1235      CHEMBL5082142  c1cnc2c(c1)CN[C@@H](CN(CCCCN1CCOCC1)[C@H]1CCCc...
# 1236       CHEMBL518924        NCCCCN(Cc1nc2ccccc2[nH]1)[C@H]1CCCc2cccnc21
# 1237      CHEMBL5092058  Cc1cn([C@H](C)CC#N)c(=O)c2cc(Cn3nc(C(F)F)cc3Cl...
# 1238      CHEMBL5177023  Cc1c(C#Cc2ccc(CN3CCC(CO)CC3)cc2)cc(C(F)F)c2cn(...
# 1239      CHEMBL5095235  CC(=O)N1CCN([C@H]2CCC[C@@H](NC(=O)c3cc4c(F)ccc...
#
#      bioactivity_class standard_value             0
# 0         intermediate         9800.0  intermediate
# 1               active           50.0        active
# 2               active           25.0        active
# 3               active          360.0        active
# 4               active          300.0        active
# ...                ...            ...           ...
# 1235          inactive        30000.0      inactive
# 1236      intermediate         4100.0  intermediate
# 1237            active           10.0        active
# 1238            active         1000.0        active
# 1239          inactive        13000.0      inactive
#
# [1240 rows x 5 columns]

# %%
df3.to_csv('drd2_bioactivity_preprocessed_data.csv', index=False)

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2023-08-20 20:18:41--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.1’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   155MB/s    in 0.5s
#
# 2023-08-20 20:18:42 (155 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.1’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following packages will be DOWNGRADED:
#
#   ca-certificates                     2023.05.30-h06a4308_0 --> 2020.1.1-0
#   certifi                          2022.12.7-py37h06a4308_0 --> 2019.11.28-py37_0
#   conda                               23.1.0-py37h06a4308_0 --> 4.8.2-py37_0
#   openssl                                 1.1.1v-h7f8727e_0 --> 1.1.1d-h7b6447c_4
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 23.7.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.6.20          |     pyhd3eb1b0_3         155 KB
#     ------------------------------------------------------------
#                                            Total:         155 KB
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2023.05.30-h06a4308_0
#   certifi            pkgs/main/linux-64::certifi-2019.11.2~ --> pkgs/main/noarch::certifi-2020.6.20-pyhd3eb1b0_3
#   openssl                                 1.1.1d-h7b6447c_4 --> 1.1.1v-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# certifi-2020.6.20    | 155 KB    | : 100% 1.0/1 [00:00<00:00,  4.42it/s]
# done
# done
# done

# %%
df4 = pd.read_csv('drd2_bioactivity_preprocessed_data.csv')

# %%
df_lipinski = lipinski(df4.canonical_smiles)

# %%
df_combined = pd.concat([df4,df_lipinski], axis=1)

# %%
#ic50 to pic50
import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)

    return x

# %%
-np.log10( (10**-9)* 100000000 )
# Out:
# 1.0

# %%
-np.log10( (10**-9)* 10000000000 )
# Out:
# -1.0

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', 1)

    return x

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
# <ipython-input-30-c8e03533cbc3>:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = input.drop('standard_value', 1)
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL303519          c1cnc(N2CCN(Cc3cccc4c3Cc3ccccc3-4)CC2)nc1
# 1          CHEMBL292943         COc1ccc(-c2cccc(CN3CCN(c4ncccn4)CC3)c2)cc1
# 2           CHEMBL61682         Fc1ccc(-c2cncc(CN3CCN(c4ccccc4F)CC3)c2)cc1
# 3           CHEMBL64487           COc1ccccc1-c1cccc(CN2CCN(c3ncccn3)CC2)c1
# 4           CHEMBL64597            c1cnc(N2CCN(Cc3cccc(-c4ccsc4)c3)CC2)nc1
# ...                 ...                                                ...
# 1235      CHEMBL5082142  c1cnc2c(c1)CN[C@@H](CN(CCCCN1CCOCC1)[C@H]1CCCc...
# 1236       CHEMBL518924        NCCCCN(Cc1nc2ccccc2[nH]1)[C@H]1CCCc2cccnc21
# 1237      CHEMBL5092058  Cc1cn([C@H](C)CC#N)c(=O)c2cc(Cn3nc(C(F)F)cc3Cl...
# 1238      CHEMBL5177023  Cc1c(C#Cc2ccc(CN3CCC(CO)CC3)cc2)cc(C(F)F)c2cn(...
# 1239      CHEMBL5095235  CC(=O)N1CCN([C@H]2CCC[C@@H](NC(=O)c3cc4c(F)ccc...
#
#      bioactivity_class       MW     LogP  NumHDonors  NumHAcceptors  \
# 0         intermediate  342.446  3.37000         0.0            4.0
# 1               active  360.461  3.47440         0.0            5.0
# 2               active  365.427  4.34900         0.0            3.0
# 3               active  360.461  3.47440         0.0            5.0
# 4               active  336.464  3.52730         0.0            5.0
# ...                ...      ...      ...         ...            ...
# 1235          inactive  435.616  2.98290         1.0            6.0
# 1236      intermediate  349.482  3.57640         2.0            4.0
# 1237            active  380.786  3.11490         0.0            7.0
# 1238            active  681.813  6.20282         2.0            9.0
# 1239          inactive  400.498  2.82052         2.0            3.0
#
#       standard_value_norm
# 0                  9800.0
# 1                    50.0
# 2                    25.0
# 3                   360.0
# 4                   300.0
# ...                   ...
# 1235              30000.0
# 1236               4100.0
# 1237                 10.0
# 1238               1000.0
# 1239              13000.0
#
# [1240 rows x 8 columns]

# %%
df_final = pIC50(df_norm)
df_final
# Out:
# <ipython-input-27-679be52d8830>:12: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = input.drop('standard_value_norm', 1)
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL303519          c1cnc(N2CCN(Cc3cccc4c3Cc3ccccc3-4)CC2)nc1
# 1          CHEMBL292943         COc1ccc(-c2cccc(CN3CCN(c4ncccn4)CC3)c2)cc1
# 2           CHEMBL61682         Fc1ccc(-c2cncc(CN3CCN(c4ccccc4F)CC3)c2)cc1
# 3           CHEMBL64487           COc1ccccc1-c1cccc(CN2CCN(c3ncccn3)CC2)c1
# 4           CHEMBL64597            c1cnc(N2CCN(Cc3cccc(-c4ccsc4)c3)CC2)nc1
# ...                 ...                                                ...
# 1235      CHEMBL5082142  c1cnc2c(c1)CN[C@@H](CN(CCCCN1CCOCC1)[C@H]1CCCc...
# 1236       CHEMBL518924        NCCCCN(Cc1nc2ccccc2[nH]1)[C@H]1CCCc2cccnc21
# 1237      CHEMBL5092058  Cc1cn([C@H](C)CC#N)c(=O)c2cc(Cn3nc(C(F)F)cc3Cl...
# 1238      CHEMBL5177023  Cc1c(C#Cc2ccc(CN3CCC(CO)CC3)cc2)cc(C(F)F)c2cn(...
# 1239      CHEMBL5095235  CC(=O)N1CCN([C@H]2CCC[C@@H](NC(=O)c3cc4c(F)ccc...
#
#      bioactivity_class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0         intermediate  342.446  3.37000         0.0            4.0  5.008774
# 1               active  360.461  3.47440         0.0            5.0  7.301030
# 2               active  365.427  4.34900         0.0            3.0  7.602060
# 3               active  360.461  3.47440         0.0            5.0  6.443697
# 4               active  336.464  3.52730         0.0            5.0  6.522879
# ...                ...      ...      ...         ...            ...       ...
# 1235          inactive  435.616  2.98290         1.0            6.0  4.522879
# 1236      intermediate  349.482  3.57640         2.0            4.0  5.387216
# 1237            active  380.786  3.11490         0.0            7.0  8.000000
# 1238            active  681.813  6.20282         2.0            9.0  6.000000
# 1239          inactive  400.498  2.82052         2.0            3.0  4.886057
#
# [1240 rows x 8 columns]

# %%
#removing intermediate class
df_2class = df_final[df_final.bioactivity_class != 'intermediate']

# %% [markdown]
# Plots

# %%
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='bioactivity_class', data=df_2class, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot_bioactivity_class.pdf')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='bioactivity_class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'pIC50', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('plot_ic50.pdf')

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics             p  alpha  \
# 0       LogP    140500.5  2.252510e-09   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'NumHDonors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics         p  alpha                      Interpretation
# 0  NumHDonors    129885.0  0.000156   0.05  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'bioactivity_class', y = 'NumHAcceptors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics        p  alpha  \
# 0  NumHAcceptors    114588.5  0.95983   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# Making our own model

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
#   inflating: __MACOSX/PaDEL-Descriptor/._config
#   inflating: PaDEL-Descriptor/PubchemFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._PubchemFingerprinter.xml
#   inflating: PaDEL-Descriptor/ExtendedFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._ExtendedFingerprinter.xml
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprinter.xml
#   inflating: PaDEL-Descriptor/GraphOnlyFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._GraphOnlyFingerprinter.xml
#   inflating: PaDEL-Descriptor/SubstructureFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprinter.xml
#   inflating: PaDEL-Descriptor/Descriptors.xls
#   inflating: __MACOSX/PaDEL-Descriptor/._Descriptors.xls
#    creating: PaDEL-Descriptor/lib/
#   inflating: __MACOSX/PaDEL-Descriptor/._lib
#   inflating: PaDEL-Descriptor/PaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/._PaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/SubstructureFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprintCount.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprintCount.xml
#   inflating: PaDEL-Descriptor/descriptors.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._descriptors.xml
#   inflating: PaDEL-Descriptor/license/lgpl-2.1.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl-2.1.txt
#   inflating: PaDEL-Descriptor/license/LICENSE.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._LICENSE.txt
#   inflating: PaDEL-Descriptor/license/README - CDK
#   inflating: __MACOSX/PaDEL-Descriptor/license/._README - CDK
#   inflating: PaDEL-Descriptor/license/lgpl.license
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl.license
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL.jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(4).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(2).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1(1).jar
#   inflating: PaDEL-Descriptor/lib/swing-worker-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._swing-worker-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(3).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(5).jar
#   inflating: PaDEL-Descriptor/lib/jama(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(1).jar
#   inflating: PaDEL-Descriptor/lib/appframework-1.0.3.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._appframework-1.0.3.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(7).jar
#   inflating: PaDEL-Descriptor/lib/vecmath1.2-1.14.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._vecmath1.2-1.14.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(6).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(2).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(4).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(5).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(2).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(3).jar
#   inflating: PaDEL-Descriptor/lib/jama(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(7).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(1).jar
#   inflating: PaDEL-Descriptor/lib/jama(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(3).jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all(1).jar
#   inflating: PaDEL-Descriptor/lib/jama.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama.jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all.jar
#   inflating: PaDEL-Descriptor/lib/jama(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(5).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(7).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(4).jar
#   inflating: PaDEL-Descriptor/lib/cdk-1.4.15.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._cdk-1.4.15.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(6).jar
#   inflating: PaDEL-Descriptor/lib/jama(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(1).jar
#   inflating: PaDEL-Descriptor/lib/guava-17.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._guava-17.0.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(5).jar

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df_2class_selection = df_2class[selection]
df_2class_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# COc1ccc(-c2cccc(CN3CCN(c4ncccn4)CC3)c2)cc1	CHEMBL292943
# Fc1ccc(-c2cncc(CN3CCN(c4ccccc4F)CC3)c2)cc1	CHEMBL61682
# COc1ccccc1-c1cccc(CN2CCN(c3ncccn3)CC2)c1	CHEMBL64487
# c1cnc(N2CCN(Cc3cccc(-c4ccsc4)c3)CC2)nc1	CHEMBL64597
# Fc1ccc(-c2cncc(CN3CCN(c4ccc(F)cc4)CC3)c2)cc1	CHEMBL291824

# %%
! cat molecule.smi | wc -l
# Out:
# 1001

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL292943 in molecule.smi (1/1001).
# Processing CHEMBL61682 in molecule.smi (2/1001).
# Processing CHEMBL64597 in molecule.smi (4/1001). Average speed: 3.86 s/mol.
# Processing CHEMBL64487 in molecule.smi (3/1001). Average speed: 7.68 s/mol.
# Processing CHEMBL291824 in molecule.smi (5/1001). Average speed: 3.09 s/mol.
# Processing CHEMBL59942 in molecule.smi (6/1001). Average speed: 2.48 s/mol.
# Processing CHEMBL61657 in molecule.smi (7/1001). Average speed: 2.28 s/mol.
# Processing CHEMBL302183 in molecule.smi (8/1001). Average speed: 1.97 s/mol.
# Processing CHEMBL555670 in molecule.smi (9/1001). Average speed: 2.33 s/mol.
# Processing CHEMBL291380 in molecule.smi (10/1001). Average speed: 2.10 s/mol.
# Processing CHEMBL40391 in molecule.smi (11/1001). Average speed: 1.76 s/mol.
# Processing CHEMBL64671 in molecule.smi (12/1001). Average speed: 1.66 s/mol.
# Processing CHEMBL62829 in molecule.smi (13/1001). Average speed: 1.63 s/mol.
# Processing CHEMBL64119 in molecule.smi (14/1001). Average speed: 1.68 s/mol.
# Processing CHEMBL302904 in molecule.smi (15/1001). Average speed: 1.48 s/mol.
# Processing CHEMBL60957 in molecule.smi (16/1001). Average speed: 1.50 s/mol.
# Processing CHEMBL356304 in molecule.smi (18/1001). Average speed: 1.40 s/mol.
# Processing CHEMBL82652 in molecule.smi (17/1001). Average speed: 1.39 s/mol.
# Processing CHEMBL147279 in molecule.smi (19/1001). Average speed: 1.29 s/mol.
# Processing CHEMBL82884 in molecule.smi (20/1001). Average speed: 1.23 s/mol.
# Processing CHEMBL56 in molecule.smi (22/1001). Average speed: 1.15 s/mol.
# Processing CHEMBL148249 in molecule.smi (21/1001). Average speed: 1.21 s/mol.
# Processing CHEMBL147226 in molecule.smi (23/1001). Average speed: 1.14 s/mol.
# Processing CHEMBL1204116 in molecule.smi (24/1001). Average speed: 1.15 s/mol.
# Processing CHEMBL42 in molecule.smi (25/1001). Average speed: 1.09 s/mol.
# Processing CHEMBL1203260 in molecule.smi (26/1001). Average speed: 1.06 s/mol.
# Processing CHEMBL1202203 in molecule.smi (27/1001). Average speed: 1.04 s/mol.
# Processing CHEMBL1202222 in molecule.smi (28/1001). Average speed: 1.01 s/mol.
# Processing CHEMBL2092961 in molecule.smi (29/1001). Average speed: 0.98 s/mol.
# Processing CHEMBL1202211 in molecule.smi (30/1001). Average speed: 0.96 s/mol.
# Processing CHEMBL1202213 in molecule.smi (31/1001). Average speed: 0.94 s/mol.
# Processing CHEMBL1202216 in molecule.smi (33/1001). Average speed: 0.90 s/mol.
# Processing CHEMBL125455 in molecule.smi (32/1001). Average speed: 0.93 s/mol.
# Processing CHEMBL1202217 in molecule.smi (34/1001). Average speed: 0.90 s/mol.
# Processing CHEMBL1202202 in molecule.smi (35/1001). Average speed: 0.87 s/mol.
# Processing CHEMBL54 in molecule.smi (36/1001). Average speed: 0.89 s/mol.
# Processing CHEMBL1202221 in molecule.smi (37/1001). Average speed: 0.84 s/mol.
# Processing CHEMBL1202220 in molecule.smi (38/1001). Average speed: 0.86 s/mol.
# Processing CHEMBL1203257 in molecule.smi (39/1001). Average speed: 0.81 s/mol.
# Processing CHEMBL1202219 in molecule.smi (40/1001). Average speed: 0.80 s/mol.
# Processing CHEMBL1202210 in molecule.smi (41/1001). Average speed: 0.79 s/mol.
# Processing CHEMBL1202215 in molecule.smi (43/1001). Average speed: 0.76 s/mol.
# Processing CHEMBL341497 in molecule.smi (42/1001). Average speed: 0.78 s/mol.
# Processing CHEMBL1202212 in molecule.smi (44/1001). Average speed: 0.76 s/mol.
# Processing CHEMBL1202209 in molecule.smi (45/1001). Average speed: 0.74 s/mol.
# Processing CHEMBL1202204 in molecule.smi (46/1001). Average speed: 0.73 s/mol.
# Processing CHEMBL1202207 in molecule.smi (47/1001). Average speed: 0.72 s/mol.
# Processing CHEMBL1204116 in molecule.smi (48/1001). Average speed: 0.72 s/mol.
# Processing CHEMBL1202208 in molecule.smi (50/1001). Average speed: 0.70 s/mol.
# Processing CHEMBL1202206 in molecule.smi (49/1001). Average speed: 0.71 s/mol.
# Processing CHEMBL1204119 in molecule.smi (51/1001). Average speed: 0.69 s/mol.
# Processing CHEMBL1202205 in molecule.smi (52/1001). Average speed: 0.70 s/mol.
# Processing CHEMBL1202224 in molecule.smi (53/1001). Average speed: 0.67 s/mol.
# Processing CHEMBL1202225 in molecule.smi (54/1001). Average speed: 0.67 s/mol.
# Processing CHEMBL1202223 in molecule.smi (55/1001). Average speed: 0.66 s/mol.
# Processing CHEMBL1202214 in molecule.smi (56/1001). Average speed: 0.65 s/mol.
# Processing CHEMBL22242 in molecule.smi (57/1001). Average speed: 0.64 s/mol.
# Processing CHEMBL831 in molecule.smi (58/1001). Average speed: 0.64 s/mol.
# Processing CHEMBL415300 in molecule.smi (59/1001). Average speed: 0.63 s/mol.
# Processing CHEMBL72292 in molecule.smi (60/1001). Average speed: 0.63 s/mol.
# Processing CHEMBL42 in molecule.smi (61/1001). Average speed: 0.62 s/mol.
# Processing CHEMBL70319 in molecule.smi (62/1001). Average speed: 0.62 s/mol.
# Processing CHEMBL54 in molecule.smi (63/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL73589 in molecule.smi (64/1001). Average speed: 0.62 s/mol.
# Processing CHEMBL83658 in molecule.smi (65/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL306474 in molecule.smi (66/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL430798 in molecule.smi (67/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL603 in molecule.smi (68/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL120055 in molecule.smi (69/1001). Average speed: 0.60 s/mol.
# Processing CHEMBL28902 in molecule.smi (70/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL160581 in molecule.smi (71/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL31714 in molecule.smi (72/1001). Average speed: 0.62 s/mol.
# Processing CHEMBL349034 in molecule.smi (73/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL164792 in molecule.smi (74/1001). Average speed: 0.62 s/mol.
# Processing CHEMBL83658 in molecule.smi (75/1001). Average speed: 0.62 s/mol.
# Processing CHEMBL331188 in molecule.smi (77/1001). Average speed: 0.62 s/mol.
# Processing CHEMBL315772 in molecule.smi (76/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL553331 in molecule.smi (78/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL305660 in molecule.smi (79/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL338611 in molecule.smi (80/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL558226 in molecule.smi (81/1001). Average speed: 0.62 s/mol.
# Processing CHEMBL67555 in molecule.smi (82/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL14376 in molecule.smi (83/1001). Average speed: 0.61 s/mol.
# Processing CHEMBL225230 in molecule.smi (85/1001). Average speed: 0.60 s/mol.
# Processing CHEMBL110362 in molecule.smi (84/1001). Average speed: 0.60 s/mol.
# Processing CHEMBL355149 in molecule.smi (86/1001). Average speed: 0.59 s/mol.
# Processing CHEMBL267044 in molecule.smi (87/1001). Average speed: 0.59 s/mol.
# Processing CHEMBL350972 in molecule.smi (88/1001). Average speed: 0.59 s/mol.
# Processing CHEMBL26736 in molecule.smi (89/1001). Average speed: 0.58 s/mol.
# Processing CHEMBL267930 in molecule.smi (91/1001). Average speed: 0.58 s/mol.
# Processing CHEMBL225230 in molecule.smi (90/1001). Average speed: 0.58 s/mol.
# Processing CHEMBL1255588 in molecule.smi (92/1001). Average speed: 0.57 s/mol.
# Processing CHEMBL39 in molecule.smi (93/1001). Average speed: 0.57 s/mol.
# Processing CHEMBL479587 in molecule.smi (94/1001). Average speed: 0.56 s/mol.
# Processing CHEMBL59 in molecule.smi (95/1001). Average speed: 0.56 s/mol.
# Processing CHEMBL1437 in molecule.smi (96/1001). Average speed: 0.56 s/mol.
# Processing CHEMBL11425 in molecule.smi (97/1001). Average speed: 0.55 s/mol.
# Processing CHEMBL416523 in molecule.smi (98/1001). Average speed: 0.55 s/mol.
# Processing CHEMBL11592 in molecule.smi (99/1001). Average speed: 0.55 s/mol.
# Processing CHEMBL116463 in molecule.smi (100/1001). Average speed: 0.54 s/mol.
# Processing CHEMBL115280 in molecule.smi (101/1001). Average speed: 0.54 s/mol.
# Processing CHEMBL325750 in molecule.smi (102/1001). Average speed: 0.54 s/mol.
# Processing CHEMBL114484 in molecule.smi (103/1001). Average speed: 0.54 s/mol.
# Processing CHEMBL326962 in molecule.smi (104/1001). Average speed: 0.54 s/mol.
# Processing CHEMBL112457 in molecule.smi (105/1001). Average speed: 0.53 s/mol.
# Processing CHEMBL115506 in molecule.smi (106/1001). Average speed: 0.53 s/mol.
# Processing CHEMBL112413 in molecule.smi (107/1001). Average speed: 0.53 s/mol.
# Processing CHEMBL115934 in molecule.smi (108/1001). Average speed: 0.53 s/mol.
# Processing CHEMBL111909 in molecule.smi (109/1001). Average speed: 0.52 s/mol.
# Processing CHEMBL113282 in molecule.smi (110/1001). Average speed: 0.52 s/mol.
# Processing CHEMBL305187 in molecule.smi (111/1001). Average speed: 0.52 s/mol.
# Processing CHEMBL320801 in molecule.smi (112/1001). Average speed: 0.52 s/mol.
# Processing CHEMBL2373204 in molecule.smi (113/1001). Average speed: 0.51 s/mol.
# Processing CHEMBL2373207 in molecule.smi (114/1001). Average speed: 0.51 s/mol.
# Processing CHEMBL359002 in molecule.smi (116/1001). Average speed: 0.51 s/mol.
# Processing CHEMBL42 in molecule.smi (115/1001). Average speed: 0.51 s/mol.
# Processing CHEMBL2373205 in molecule.smi (118/1001). Average speed: 0.51 s/mol.
# Processing CHEMBL356358 in molecule.smi (117/1001). Average speed: 0.51 s/mol.
# Processing CHEMBL144811 in molecule.smi (119/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL26929 in molecule.smi (120/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL2373206 in molecule.smi (121/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL424125 in molecule.smi (122/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL2373210 in molecule.smi (123/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL54 in molecule.smi (124/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL286725 in molecule.smi (125/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL357448 in molecule.smi (126/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL26677 in molecule.smi (127/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL93403 in molecule.smi (128/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL147483 in molecule.smi (129/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL134423 in molecule.smi (130/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL134423 in molecule.smi (131/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL84931 in molecule.smi (132/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL315772 in molecule.smi (133/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL314107 in molecule.smi (134/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL83658 in molecule.smi (135/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL85735 in molecule.smi (136/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL611207 in molecule.smi (137/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL611207 in molecule.smi (138/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL608530 in molecule.smi (139/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL301242 in molecule.smi (140/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL59725 in molecule.smi (141/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL139926 in molecule.smi (142/1001). Average speed: 0.50 s/mol.
# Processing CHEMBL302374 in molecule.smi (143/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL262724 in molecule.smi (144/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL71327 in molecule.smi (146/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL69451 in molecule.smi (145/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL71865 in molecule.smi (147/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL180060 in molecule.smi (148/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL370713 in molecule.smi (149/1001). Average speed: 0.49 s/mol.
# Processing CHEMBL194493 in molecule.smi (150/1001). Average speed: 0.48 s/mol.
# Processing CHEMBL195057 in molecule.smi (151/1001). Average speed: 0.48 s/mol.
# Processing CHEMBL366904 in molecule.smi (152/1001). Average speed: 0.48 s/mol.
# Processing CHEMBL175734 in molecule.smi (153/1001). Average speed: 0.48 s/mol.
# Processing CHEMBL180010 in molecule.smi (154/1001). Average speed: 0.48 s/mol.
# Processing CHEMBL301242 in molecule.smi (155/1001). Average speed: 0.48 s/mol.
# Processing CHEMBL42 in molecule.smi (156/1001). Average speed: 0.48 s/mol.
# Processing CHEMBL1255588 in molecule.smi (157/1001). Average speed: 0.48 s/mol.
# Processing CHEMBL277120 in molecule.smi (158/1001). Average speed: 0.48 s/mol.
# Processing CHEMBL708 in molecule.smi (160/1001). Average speed: 0.47 s/mol.
# Processing CHEMBL54786 in molecule.smi (159/1001). Average speed: 0.47 s/mol.
# Processing CHEMBL69584 in molecule.smi (161/1001). Average speed: 0.47 s/mol.
# Processing CHEMBL107742 in molecule.smi (162/1001). Average speed: 0.47 s/mol.
# Processing CHEMBL198949 in molecule.smi (164/1001). Average speed: 0.47 s/mol.
# Processing CHEMBL320597 in molecule.smi (163/1001). Average speed: 0.47 s/mol.
# Processing CHEMBL383577 in molecule.smi (166/1001). Average speed: 0.46 s/mol.
# Processing CHEMBL34291 in molecule.smi (165/1001). Average speed: 0.47 s/mol.
# Processing CHEMBL201878 in molecule.smi (167/1001). Average speed: 0.46 s/mol.
# Processing CHEMBL201946 in molecule.smi (168/1001). Average speed: 0.46 s/mol.
# Processing CHEMBL201621 in molecule.smi (169/1001). Average speed: 0.46 s/mol.
# Processing CHEMBL2448165 in molecule.smi (170/1001). Average speed: 0.46 s/mol.
# Processing CHEMBL1729 in molecule.smi (171/1001). Average speed: 0.46 s/mol.
# Processing CHEMBL202434 in molecule.smi (172/1001). Average speed: 0.45 s/mol.
# Processing CHEMBL372312 in molecule.smi (173/1001). Average speed: 0.45 s/mol.
# Processing CHEMBL377498 in molecule.smi (174/1001). Average speed: 0.45 s/mol.
# Processing CHEMBL202939 in molecule.smi (175/1001). Average speed: 0.45 s/mol.
# Processing CHEMBL369997 in molecule.smi (176/1001). Average speed: 0.45 s/mol.
# Processing CHEMBL204759 in molecule.smi (177/1001). Average speed: 0.45 s/mol.
# Processing CHEMBL204254 in molecule.smi (178/1001). Average speed: 0.45 s/mol.
# Processing CHEMBL203403 in molecule.smi (179/1001). Average speed: 0.45 s/mol.
# Processing CHEMBL379679 in molecule.smi (181/1001). Average speed: 0.44 s/mol.
# Processing CHEMBL204490 in molecule.smi (180/1001). Average speed: 0.44 s/mol.
# Processing CHEMBL379446 in molecule.smi (183/1001). Average speed: 0.44 s/mol.
# Processing CHEMBL381127 in molecule.smi (182/1001). Average speed: 0.44 s/mol.
# Processing CHEMBL202420 in molecule.smi (185/1001). Average speed: 0.43 s/mol.
# Processing CHEMBL203563 in molecule.smi (184/1001). Average speed: 0.43 s/mol.
# Processing CHEMBL377050 in molecule.smi (187/1001). Average speed: 0.43 s/mol.
# Processing CHEMBL2113241 in molecule.smi (186/1001). Average speed: 0.43 s/mol.
# Processing CHEMBL213106 in molecule.smi (188/1001). Average speed: 0.43 s/mol.
# Processing CHEMBL212075 in molecule.smi (189/1001). Average speed: 0.43 s/mol.
# Processing CHEMBL214190 in molecule.smi (190/1001). Average speed: 0.43 s/mol.
# Processing CHEMBL385350 in molecule.smi (191/1001). Average speed: 0.43 s/mol.
# Processing CHEMBL214954 in molecule.smi (192/1001). Average speed: 0.42 s/mol.
# Processing CHEMBL385230 in molecule.smi (193/1001). Average speed: 0.42 s/mol.
# Processing CHEMBL215849 in molecule.smi (194/1001). Average speed: 0.42 s/mol.
# Processing CHEMBL214440 in molecule.smi (195/1001). Average speed: 0.42 s/mol.
# Processing CHEMBL212188 in molecule.smi (196/1001). Average speed: 0.42 s/mol.
# Processing CHEMBL212298 in molecule.smi (198/1001). Average speed: 0.42 s/mol.
# Processing CHEMBL212189 in molecule.smi (197/1001). Average speed: 0.42 s/mol.
# Processing CHEMBL212902 in molecule.smi (200/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL212847 in molecule.smi (199/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL214343 in molecule.smi (202/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL384529 in molecule.smi (201/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL385826 in molecule.smi (204/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL211985 in molecule.smi (203/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL212782 in molecule.smi (205/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL213572 in molecule.smi (206/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL212831 in molecule.smi (207/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL261957 in molecule.smi (208/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL376639 in molecule.smi (209/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL213700 in molecule.smi (210/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL376955 in molecule.smi (211/1001). Average speed: 0.41 s/mol.
# Processing CHEMBL212607 in molecule.smi (213/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL411545 in molecule.smi (212/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL386867 in molecule.smi (214/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL213246 in molecule.smi (215/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL215670 in molecule.smi (216/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL438961 in molecule.smi (217/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL211972 in molecule.smi (218/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL212804 in molecule.smi (219/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL212545 in molecule.smi (220/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL215569 in molecule.smi (221/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL213558 in molecule.smi (222/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL378324 in molecule.smi (223/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL214203 in molecule.smi (224/1001). Average speed: 0.40 s/mol.
# Processing CHEMBL215704 in molecule.smi (225/1001). Average speed: 0.40 s/mol.
# Processing CHEMB
1001). Average speed: 0.34 s/mol.
# Processing CHEMBL4741908 in molecule.smi (981/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL4749223 in molecule.smi (983/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL4777098 in molecule.smi (984/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL4777475 in molecule.smi (985/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL4751542 in molecule.smi (987/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL4759331 in molecule.smi (986/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL1814790 in molecule.smi (989/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL4764679 in molecule.smi (988/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL3306803 in molecule.smi (990/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL3306803 in molecule.smi (991/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL4867978 in molecule.smi (992/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL5076569 in molecule.smi (993/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL5093818 in molecule.smi (994/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL5085511 in molecule.smi (995/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL5077132 in molecule.smi (996/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL5083458 in molecule.smi (997/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL5082142 in molecule.smi (998/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL5092058 in molecule.smi (999/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL5177023 in molecule.smi (1000/1001). Average speed: 0.34 s/mol.
# Processing CHEMBL5095235 in molecule.smi (1001/1001). Average speed: 0.34 s/mol.
# Descriptor calculation completed in 5 mins 41.136 secs . Average speed: 0.34 s/mol.

# %%
df_2class_X = pd.read_csv('descriptors_output.csv')

# %%
df_2class_X = df_2class_X.drop(columns=['Name'])

# %%
df_2class_Y = df_2class['pIC50']

# %%
dataset = pd.concat([df_2class_X,df_2class_Y], axis=1)

# %%
dataset_cleaned = dataset.dropna()

# %%
dataset_cleaned.to_csv('drd2_bioactivity_data_3class_pIC50_pubchem_fp.csv', index=False)

# %%
df_model = pd.read_csv('drd2_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df_model.drop('pIC50', axis=1)
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
X = selection.fit_transform(X)

# %%
Y = df_model.pIC50

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# %%
def pls_1(X, Y, num_components):
    X = X - np.mean(X, axis=0)
    Y = Y - np.mean(Y, axis=0)

    T = np.zeros((X.shape[0], num_components))
    P = np.zeros((X.shape[1], num_components))
    W = np.zeros((X.shape[1], num_components))
    B = np.zeros(num_components)

    for i in range(num_components):
        w = np.dot(X.T, Y) / np.linalg.norm(np.dot(X.T, Y))
        t = np.dot(X, w)
        p = np.dot(X.T, t) / np.dot(t.T, t)
        b = np.dot(t.T, Y) / np.dot(t.T, t)

        T[:,i] = t.flatten()
        W[:,i] = w.flatten()
        P[:,i] = p.flatten()
        B[i] = b

        X = X - np.outer(t, p.T)
        Y = Y - b * t

    return T, W, P, B

# %%
T, W, P, B = pls_1(X_test, Y_test, num_components=2)

print("T (scores):", T)
print("W (weights):", W)
print("P (loadings):", P)
print("B (regressions coefficients):", B)

# %%
def predict_pls_1(X_new, W, B, num_components):
    T_new = np.dot(X_new, W[:,:num_components])
    Y_pred = np.dot(T_new, B[:num_components].T)
    return Y_pred

# %%
Y_pred = predict_pls_1(X_test, W, B, num_components=2)

# %%
sns.set(color_codes=True)
sns.set_style("white")
ax = sns.regplot(x=Y_test, y=Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(3, 10)
ax.set_ylim(-5, 5)
ax.figure.set_size_inches(5, 5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
r2 = r2_score(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 44.93949500147909

# %%
corr_matrix = np.corrcoef(Y_test, Y_pred)
corr = corr_matrix[0,1]
R_sq = corr**2
print(f"R squared: {R_sq}")
# Out:
# R squared: 0.11215009702701328
